# %%
import pandas as pd

# %%
surveys_df = pandas.read_csv('surveys.csv')

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df['day']
# Out:
# 0        16
# 1        16
# 2        16
# 3        16
# 4        16
# 5        16
# 6        16
# 7        16
# 8        16
# 9        16
# 10       16
# 11       16
# 12       16
# 13       16
# 14       16
# 15       16
# 16       16
# 17       16
# 18       16
# 19       17
# 20       17
# 21       17
# 22       17
# 23       17
# 24       17
# 25       17
# 26       17
# 27       17
# 28       17
# 29       17
#          ..
# 35519    31
# 35520    31
# 35521    31
# 35522    31
# 35523    31
# 35524    31
# 35525    31
# 35526    31
# 35527    31
# 35528    31
# 35529    31
# 35530    31
# 35531    31
# 35532    31
# 35533    31
# 35534    31
# 35535    31
# 35536    31
# 35537    31
# 35538    31
# 35539    31
# 35540    31
# 35541    31
# 35542    31
# 35543    31
# 35544    31
# 35545    31
# 35546    31
# 35547    31
# 35548    31
# Name: day, dtype: int64

# %%
pd.unique( surveys_df['sex'])
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
pd.unique( surveys_df['plot_id'])
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
surveys_df['weight'].count()
# Out:
# 32283

# %%
%
# Out:
# ERROR: Line magic function `%` not found.

# %%
import matplotlib

# %%
# Out:
#   File "<ipython-input-54-fd0a0b430052>", line 1
#     species_counts - surveys_df.groupby(‘species_id’).count()
#                                                    ^
# SyntaxError: invalid character in identifier

# %%
species_df = pandas.read_csv('species.csv')

# %%
species_df.count()
# Out:
# species_id    54
# genus         54
# species       54
# taxa          54
# dtype: int64

# %%
surveys_df.groupby('species_id').count()
# Out:
#             record_id  month    day   year  plot_id    sex  hindfoot_length  \
# species_id
# AB                303    303    303    303      303      0                0
# AH                437    437    437    437      437      1                2
# AS                  2      2      2      2        2      0                0
# BA                 46     46     46     46       46     45               45
# CB                 50     50     50     50       50      0                0
# CM                 13     13     13     13       13      0                0
# CQ                 16     16     16     16       16      0                0
# CS                  1      1      1      1        1      0                0
# CT                  1      1      1      1        1      0                0
# CU                  1      1      1      1        1      0                0
# CV                  1      1      1      1        1      0                0
# ...

# %%
species_df.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-1744cfb01ac7> in <module>()
# ----> 1 species_df.plot(kind='bar')
#
# /Users/rsbadmin/anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3738                           fontsize=fontsize, colormap=colormap, table=table,
#    3739                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3740                           sort_columns=sort_columns, **kwds)
#    3741     __call__.__doc__ = plot_frame.__doc__
#    3742
#
# ...

# %%
surveys_df = pd.read_csv ("surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
species_df = pd.read_csv ("species.csv")

# %%
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
surveysub = surveys_df.head(10)

# %%
surveysubLast10 = surveys_df.tail(20)

# %%
surveysubLast10
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35529      35530     12   31  2002       13         OT    F             20.0
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35531      35532     12   31  2002       14         DM    F             34.0
# 35532      35533     12   31  2002       14         DM    F             36.0
# 35533      35534     12   31  2002       14         DM    M             37.0
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# ...

# %%
year80 = surveys_df[surveys_df['year'] == 1980]
year82 = surveys_df[surveys_df['year'] == 1980]

# %%
year82 = year82.reset_index()
year82
# Out:
#       index  record_id  month  day  year  plot_id species_id  sex  \
# 0      2270       2271      1   15  1980        8         DO    M
# 1      2271       2272      1   15  1980       11         PF    F
# 2      2272       2273      1   15  1980       18         DM    F
# 3      2273       2274      1   15  1980       11         DM    M
# 4      2274       2275      1   15  1980        8         DO    F
# 5      2275       2276      1   15  1980       11         DS    M
# 6      2276       2277      1   15  1980        8         PF    M
# 7      2277       2278      1   15  1980        9         OT    M
# 8      2278       2279      1   15  1980       11         DM    F
# 9      2279       2280      1   15  1980       21         OT    F
# 10     2280       2281      1   15  1980       11         OL    M
# 11     2281       2282      1   15  1980       17         DM    F
# 12     2282       2283      1   15  1980       11         OL    M
# ...

# %%
surveysSub = surveys_df()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-892dc7f5ad53> in <module>()
# ----> 1 surveysSub = surveys_df()
#
# TypeError: 'DataFrame' object is not callable
